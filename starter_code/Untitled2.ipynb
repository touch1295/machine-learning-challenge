# %%
# Import libraries
import pandas as pd

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
# Read CSV file 
df = pd.read_csv("exoplanet_data.csv")

# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')

# Drop the null rows
df = df.dropna()
df.head(10)
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
# 5       CONFIRMED              0              0              0              0
# 6       CONFIRMED              0              0              0              0
# 7       CONFIRMED              0              0              0              0
# 8       CONFIRMED              0              1              0              0
# 9       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
# 5    2.566589     1.780000e-05    -1.780000e-05   179.554370
# 6   16.068647     1.090000e-05    -1.090000e-05   173.621937
# 7    2.470613     2.700000e-08    -2.700000e-08   122.763305
# 8    2.204735     4.300000e-08    -4.300000e-08   121.358542
# 9    3.522498     1.980000e-07    -1.980000e-07   121.119423
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
# 5          0.004610  ...            -232      4.486           0.054
# 6          0.000517  ...             -83      4.485           0.083
# 7          0.000009  ...             -78      4.457           0.024
# 8          0.000016  ...             -89      4.019           0.033
# 9          0.000047  ...            -137      4.169           0.055
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
# 5          -0.229     0.972          0.315         -0.105  296.28613
# 6          -0.028     0.848          0.033         -0.072  286.99948
# 7          -0.024     0.964          0.038         -0.038  286.80847
# 8          -0.027     1.952          0.099         -0.110  292.24728
# 9          -0.045     1.451          0.110         -0.110  281.28812
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
# 5  48.224670      15.714
# 6  48.375790      15.841
# 7  49.316399      11.338
# 8  47.969521      10.463
# 9  42.451080      13.563
#
# [10 rows x 41 columns]

# %% [markdown]
# # Select features (columns)

# %%
# Set features
# selected_features = df[['names', 'of', 'selected', 'features', 'here']]
selected_features = df

# %% [markdown]
# # Create a Train Test Split
# Use koi_disposition for the y values

# %%
# Assign x and y values
X = df.drop("koi_disposition", axis=1)
y = df["koi_disposition"]

print(X.shape, y.shape)
# Out:
# (6991, 40) (6991,)

# %%
# Import Dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler


# Split data into training and testing
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=115, stratify=y)

# %%
X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 2700              0              0              0              0   31.804760
# 21                0              0              0              0    4.280964
# 5040              0              1              1              0    0.829019
# 2795              0              0              1              0    1.387838
# 1765              0              0              0              0   14.383227
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 2700         0.000091        -0.000091    190.25413           0.00224
# 21           0.000006        -0.000006    171.89659           0.00115
# 5040         0.000002        -0.000002    131.46667           0.00401
# 2795         0.000006        -0.000006    132.11351           0.00318
# 1765         0.000086        -0.000086    140.57648           0.00530
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 2700          -0.00224  ...            -128      4.235           0.143
# 21            -0.00115  ...            -169      4.564           0.032
# 5040          -0.00401  ...            -255      4.271           0.124
# 2795          -0.00318  ...            -219      4.442           0.054
# 1765          -0.00530  ...            -135      4.249           0.137
#
#       koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 2700          -0.117     1.356          0.212         -0.259  287.62082
# 21            -0.168     0.831          0.207         -0.069  294.26581
# 5040          -0.186     1.328          0.408         -0.220  296.03485
# 2795          -0.216     1.044          0.335         -0.112  295.64212
# 1765          -0.112     1.291          0.216         -0.216  290.08276
#
#             dec  koi_kepmag
# 2700  43.141647      13.178
# 21    49.314091      15.356
# 5040  45.490822      14.661
# 2795  48.773071      15.167
# 1765  50.863480      13.312
#
# [5 rows x 40 columns]

# %% [markdown]
# # Pre-processing
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale the data
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# # Train the Model - Random Forest
# Use Random Forest model

# %%
# Create the Random Forest Model
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf = rf.fit(X_train_scaled, y_train)

# %%
print(f"Training Data Score: {rf.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {rf.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 1.0
# Testing Data Score: 0.8913043478260869

# %%
# Random Forests in sklearn will automatically calculate feature importance
importances = rf.feature_importances_
importances
# Out:
# array([0.09876747, 0.07839172, 0.10882241, 0.0365203 , 0.02172281,
#        0.01412592, 0.0168555 , 0.01392409, 0.02164395, 0.02422582,
#        0.01718075, 0.0113747 , 0.01057322, 0.02376202, 0.03119764,
#        0.03525481, 0.02109794, 0.01385585, 0.01576133, 0.04802435,
#        0.03214255, 0.02408514, 0.01511208, 0.0136232 , 0.01906513,
#        0.01081241, 0.05804892, 0.00246703, 0.00979773, 0.03247569,
#        0.02362865, 0.01075107, 0.00866096, 0.01178761, 0.00839778,
#        0.01317398, 0.00834661, 0.01262104, 0.01129623, 0.01062359])

# %%
# Sort the features by their importance
sorted(zip(rf.feature_importances_, selected_features), reverse=True)
# Out:
# [(0.10882240791515979, 'koi_fpflag_ss'),
#  (0.09876747158910958, 'koi_disposition'),
#  (0.07839172478736862, 'koi_fpflag_nt'),
#  (0.05804891990250059, 'koi_insol_err2'),
#  (0.04802434672155093, 'koi_depth_err2'),
#  (0.03652030399542776, 'koi_fpflag_co'),
#  (0.03525481228166585, 'koi_duration_err1'),
#  (0.03247568629259812, 'koi_steff'),
#  (0.03214254704751626, 'koi_prad'),
#  (0.0311976350839224, 'koi_duration'),
#  (0.024225817018324186, 'koi_time0bk_err1'),
#  (0.024085140603921612, 'koi_prad_err1'),
#  (0.02376202004302771, 'koi_impact_err2'),
#  (0.023628653059182776, 'koi_steff_err1'),
#  (0.021722814099790932, 'koi_fpflag_ec'),
#  (0.02164394683179, 'koi_time0bk'),
#  (0.021097937551397553, 'koi_duration_err2'),
#  (0.019065130100339677, 'koi_insol'),
#  (0.017180751961555996, 'koi_time0bk_err2'),
#  (0.016855503788627768, 'koi_period_err1'),
#  (0.01576132612125739, 'koi_depth_err1'),
#  (0.015112078713263097, 'koi_prad_err2'),
#  (0.014125920928443557, 'koi_period'),
#  (0.013924092750452612, 'koi_period_err2'),
#  (0.013855853045063024, 'koi_depth'),
#  (0.013623204892444968, 'koi_teq'),
#  (0.013173976725025975, 'koi_srad'),
#  (0.012621036465616216, 'koi_srad_err2'),
#  (0.011787614264794135, 'koi_slogg_err1'),
#  (0.011374699072567473, 'koi_impact'),
#  (0.011296228227501183, 'ra'),
#  (0.010812408891759207, 'koi_insol_err1'),
#  (0.010751072775617003, 'koi_steff_err2'),
#  (0.010623585464771833, 'dec'),
#  (0.01057321840356766, 'koi_impact_err1'),
#  (0.009797729639960161, 'koi_tce_plnt_num'),
#  (0.008660958844013031, 'koi_slogg'),
#  (0.008397784913719798, 'koi_slogg_err2'),
#  (0.008346606483391287, 'koi_srad_err1'),
#  (0.002467032701992277, 'koi_model_snr')]

# %% [markdown]
# # Hyperparameter tuning
# Use GridSearchCV to tune the Random Forest model's parameters

# %%
# Create the GridSearchCV model
from sklearn.model_selection import GridSearchCV
param_grid = {'n_estimators': [250, 300, 350],
              'max_depth': [125, 150, 175]}
grid = GridSearchCV(rf, param_grid, verbose=3)

# %%
# Fit the Random Forest model using the grid search estimator. 
# This will take the Random Forest model and try each combination of parameters
grid.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] max_depth=125, n_estimators=250 .................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ..... max_depth=125, n_estimators=250, score=0.899, total=   3.0s
# [CV] max_depth=125, n_estimators=250 .................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    3.0s remaining:    0.0s
# [CV] ..... max_depth=125, n_estimators=250, score=0.893, total=   3.0s
# [CV] max_depth=125, n_estimators=250 .................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    6.0s remaining:    0.0s
# [CV] ..... max_depth=125, n_estimators=250, score=0.898, total=   3.0s
# [CV] max_depth=125, n_estimators=250 .................................
# [CV] ..... max_depth=125, n_estimators=250, score=0.896, total=   2.9s
# [CV] max_depth=125, n_estimators=250 .................................
# [CV] ..... max_depth=125, n_estimators=250, score=0.895, total=   3.0s
# [CV] max_depth=125, n_estimators=300 .................................
# [CV] ..... max_depth=125, n_estimators=300, score=0.900, total=   3.6s
# [CV] max_depth=125, n_estimators=300 .................................
# [CV] ..... max_depth=125, n_estimators=300, score=0.890, total=   3.6s
# [CV] max_depth=125, n_estimators=300 .................................
# [CV] ..... max_depth=125, n_estimators=300, score=0.899, total=   3.5s
# [CV] max_depth=125, n_estimators=300 .................................
# [CV] ..... max_depth=125, n_estimators=300, score=0.891, total=   3.6s
# [CV] max_depth=125, n_estimators=300 .................................
# [CV] ..... max_depth=125, n_estimators=300, score=0.901, total=   3.6s
# [CV] max_depth=125, n_estimators=350 .................................
# [CV] ..... max_depth=125, n_estimators=350, score=0.904, total=   4.2s
# [CV] max_depth=125, n_estimators=350 .................................
# [CV] ..... max_depth=125, n_estimators=350, score=0.897, total=   4.2s
# [CV] max_depth=125, n_estimators=350 .................................
# [CV] ..... max_depth=125, n_estimators=350, score=0.901, total=   4.3s
# [CV] max_depth=125, n_estimators=350 .................................
# [CV] ..... max_depth=125, n_estimators=350, score=0.896, total=   4.3s
# [CV] max_depth=125, n_estimators=350 .................................
# [CV] ..... max_depth=125, n_estimators=350, score=0.895, total=   4.1s
# [CV] max_depth=150, n_estimators=250 .................................
# [CV] ..... max_depth=150, n_estimators=250, score=0.899, total=   3.0s
# [CV] max_depth=150, n_estimators=250 .................................
# [CV] ..... max_depth=150, n_estimators=250, score=0.892, total=   3.0s
# [CV] max_depth=150, n_estimators=250 .................................
# [CV] ..... max_depth=150, n_estimators=250, score=0.897, total=   3.0s
# [CV] max_depth=150, n_estimators=250 .................................
# [CV] ..... max_depth=150, n_estimators=250, score=0.892, total=   3.0s
# [CV] max_depth=150, n_estimators=250 .................................
# [CV] ..... max_depth=150, n_estimators=250, score=0.895, total=   3.1s
# [CV] max_depth=150, n_estimators=300 .................................
# [CV] ..... max_depth=150, n_estimators=300, score=0.898, total=   3.7s
# [CV] max_depth=150, n_estimators=300 .................................
# [CV] ..... max_depth=150, n_estimators=300, score=0.890, total=   3.8s
# [CV] max_depth=150, n_estimators=300 .................................
# [CV] ..... max_depth=150, n_estimators=300, score=0.895, total=   3.8s
# [CV] max_depth=150, n_estimators=300 .................................
# [CV] ..... max_depth=150, n_estimators=300, score=0.898, total=   3.6s
# [CV] max_depth=150, n_estimators=300 .................................
# [CV] ..... max_depth=150, n_estimators=300, score=0.897, total=   3.8s
# [CV] max_depth=150, n_estimators=350 .................................
# [CV] ..... max_depth=150, n_estimators=350, score=0.903, total=   4.3s
# [CV] max_depth=150, n_estimators=350 .................................
# [CV] ..... max_depth=150, n_estimators=350, score=0.896, total=   4.4s
# [CV] max_depth=150, n_estimators=350 .................................
# [CV] ..... max_depth=150, n_estimators=350, score=0.898, total=   4.3s
# [CV] max_depth=150, n_estimators=350 .................................
# [CV] ..... max_depth=150, n_estimators=350, score=0.898, total=   4.4s
# [CV] max_depth=150, n_estimators=350 .................................
# [CV] ..... max_depth=150, n_estimators=350, score=0.896, total=   4.3s
# [CV] max_depth=175, n_estimators=250 .................................
# [CV] ..... max_depth=175, n_estimators=250, score=0.900, total=   3.2s
# [CV] max_depth=175, n_estimators=250 .................................
# [CV] ..... max_depth=175, n_estimators=250, score=0.886, total=   3.1s
# [CV] max_depth=175, n_estimators=250 .................................
# [CV] ..... max_depth=175, n_estimators=250, score=0.895, total=   3.1s
# [CV] max_depth=175, n_estimators=250 .................................
# [CV] ..... max_depth=175, n_estimators=250, score=0.893, total=   3.1s
# [CV] max_depth=175, n_estimators=250 .................................
# [CV] ..... max_depth=175, n_estimators=250, score=0.899, total=   3.1s
# [CV] max_depth=175, n_estimators=300 .................................
# [CV] ..... max_depth=175, n_estimators=300, score=0.907, total=   3.8s
# [CV] max_depth=175, n_estimators=300 .................................
# [CV] ..... max_depth=175, n_estimators=300, score=0.895, total=   3.6s
# [CV] max_depth=175, n_estimators=300 .................................
# [CV] ..... max_depth=175, n_estimators=300, score=0.894, total=   3.6s
# [CV] max_depth=175, n_estimators=300 .................................
# [CV] ..... max_depth=175, n_estimators=300, score=0.899, total=   3.6s
# [CV] max_depth=175, n_estimators=300 .................................
# [CV] ..... max_depth=175, n_estimators=300, score=0.899, total=   3.6s
# [CV] max_depth=175, n_estimators=350 .................................
# [CV] ..... max_depth=175, n_estimators=350, score=0.902, total=   4.4s
# [CV] max_depth=175, n_estimators=350 .................................
# [CV] ..... max_depth=175, n_estimators=350, score=0.891, total=   4.4s
# [CV] max_depth=175, n_estimators=350 .................................
# [CV] ..... max_depth=175, n_estimators=350, score=0.896, total=   4.3s
# [CV] max_depth=175, n_estimators=350 .................................
# [CV] ..... max_depth=175, n_estimators=350, score=0.892, total=   4.3s
# [CV] max_depth=175, n_estimators=350 .................................
# [CV] ..... max_depth=175, n_estimators=350, score=0.897, total=   4.4s
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed:  2.8min finished
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [125, 150, 175],
#                          'n_estimators': [250, 300, 350]},
#              verbose=3)

# %%
# List the best parameters for this dataset
print(f"Best Parameters: {grid.best_params_}")

# List the best score
print(f"Best Score: {grid.best_score_}")
# Out:
# Best Parameters: {'max_depth': 175, 'n_estimators': 300}
# Best Score: 0.8987221563248168

# %%
print(f"Training Grid Score: {grid.score(X_train_scaled, y_train)}")
print(f"Testing Grid Score: {grid.score(X_test_scaled, y_test)}")
# Out:
# Training Grid Score: 1.0
# Testing Grid Score: 0.8901601830663616

# %%
# Make predictions with the hypertuned model
predictions = grid.predict(X_test_scaled)

# %%
 #Calculate classification report
from sklearn.metrics import classification_report
print(classification_report(y_test, predictions))
# Out:
#   File "<ipython-input-18-b72f44597ccf>", line 1
#     Calculate classification report
#               ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Save the Model

# %%
# Save the model 

import joblib
filename = 'MYCROFTXTREEM_RF.sav'
joblib.dump(rf, filename)

# %% [markdown]
# # Conclusion
# The f1-score of FALSE POSITIVE for Random Forest model is closer to 1 (0.99) meaning it can predict FALSE POSITIVE well and it's reliable.
#
# The Grid score from the hyperparameter tuning boost the Random Forest score higher Training Data Score: 0.9954224680526416 changes to 1 Testing Data Score: 0.8792906178489702 changes to 0.8895881006864989 Best Score: 0.8930001907304979
#
# However, Random Forest model's best score of (0.8930001907304979) seems better than SVM model (0.8706847224871257) when comparing the scores.
