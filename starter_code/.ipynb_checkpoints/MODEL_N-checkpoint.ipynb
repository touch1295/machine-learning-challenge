# %%
# import the library
import pandas as pd

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
# Read CSV file 
df = pd.read_csv("exoplanet_data.csv")

# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')

# Drop the null rows
df = df.dropna()
df.head(10)
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
# 5       CONFIRMED              0              0              0              0
# 6       CONFIRMED              0              0              0              0
# 7       CONFIRMED              0              0              0              0
# 8       CONFIRMED              0              1              0              0
# 9       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
# 5    2.566589     1.780000e-05    -1.780000e-05   179.554370
# 6   16.068647     1.090000e-05    -1.090000e-05   173.621937
# 7    2.470613     2.700000e-08    -2.700000e-08   122.763305
# 8    2.204735     4.300000e-08    -4.300000e-08   121.358542
# 9    3.522498     1.980000e-07    -1.980000e-07   121.119423
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
# 5          0.004610  ...            -232      4.486           0.054
# 6          0.000517  ...             -83      4.485           0.083
# 7          0.000009  ...             -78      4.457           0.024
# 8          0.000016  ...             -89      4.019           0.033
# 9          0.000047  ...            -137      4.169           0.055
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
# 5          -0.229     0.972          0.315         -0.105  296.28613
# 6          -0.028     0.848          0.033         -0.072  286.99948
# 7          -0.024     0.964          0.038         -0.038  286.80847
# 8          -0.027     1.952          0.099         -0.110  292.24728
# 9          -0.045     1.451          0.110         -0.110  281.28812
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
# 5  48.224670      15.714
# 6  48.375790      15.841
# 7  49.316399      11.338
# 8  47.969521      10.463
# 9  42.451080      13.563
#
# [10 rows x 41 columns]

# %%
# Visualizing data

# %% [markdown]
# # Select features (columns)

# %%
# Set features
# selected_features = df[['names', 'of', 'selected', 'features', 'here']]
selected_features = df

# %% [markdown]
# # Create a Train Test Split
# Use koi_disposition for the y values

# %%
# Assign x and y values
X = df.drop("koi_disposition", axis=1)
y = df["koi_disposition"]

print(X.shape, y.shape)
# Out:
# (6991, 40) (6991,)

# %%
# Import Dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical

# Split data into training and testing
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=115, stratify=y)

# %%
X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 2700              0              0              0              0   31.804760
# 21                0              0              0              0    4.280964
# 5040              0              1              1              0    0.829019
# 2795              0              0              1              0    1.387838
# 1765              0              0              0              0   14.383227
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 2700         0.000091        -0.000091    190.25413           0.00224
# 21           0.000006        -0.000006    171.89659           0.00115
# 5040         0.000002        -0.000002    131.46667           0.00401
# 2795         0.000006        -0.000006    132.11351           0.00318
# 1765         0.000086        -0.000086    140.57648           0.00530
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 2700          -0.00224  ...            -128      4.235           0.143
# 21            -0.00115  ...            -169      4.564           0.032
# 5040          -0.00401  ...            -255      4.271           0.124
# 2795          -0.00318  ...            -219      4.442           0.054
# 1765          -0.00530  ...            -135      4.249           0.137
#
#       koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 2700          -0.117     1.356          0.212         -0.259  287.62082
# 21            -0.168     0.831          0.207         -0.069  294.26581
# 5040          -0.186     1.328          0.408         -0.220  296.03485
# 2795          -0.216     1.044          0.335         -0.112  295.64212
# 1765          -0.112     1.291          0.216         -0.216  290.08276
#
#             dec  koi_kepmag
# 2700  43.141647      13.178
# 21    49.314091      15.356
# 5040  45.490822      14.661
# 2795  48.773071      15.167
# 1765  50.863480      13.312
#
# [5 rows x 40 columns]

# %% [markdown]
# # Pre-processing

# %%
# Scale the data
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# # Train Model - Neural Network
# Use Neural Network model

# %%
from tensorflow.keras.utils import to_categorical

# %%
# Step 1: Label encoder
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# %%
# Step 2: Convert encoded labels to one-hot-encoding
y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)

# %%
print(label_encoder.classes_)
# Out:
# ['CANDIDATE' 'CONFIRMED' 'FALSE POSITIVE']

# %%
label_encoder.fit(y)
encoded_y = label_encoder.transform(y)
pd.plotting.scatter_matrix(X, c=encoded_y, figsize=(40, 40));

# %%
# first, create a normal neural network 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()
model.add(Dense(units=10, activation='relu', input_dim=40))
model.add(Dense(units=3, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 10)                410
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 33
# =================================================================
# Total params: 443
# Trainable params: 443
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Fit the model to the training data
model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=100,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/100
# 164/164 - 1s - loss: 1.0338 - accuracy: 0.4969
# Epoch 2/100
# 164/164 - 0s - loss: 0.8681 - accuracy: 0.5951
# Epoch 3/100
# 164/164 - 0s - loss: 0.7014 - accuracy: 0.7393
# Epoch 4/100
# 164/164 - 0s - loss: 0.5785 - accuracy: 0.7555
# Epoch 5/100
# 164/164 - 0s - loss: 0.5054 - accuracy: 0.7728
# Epoch 6/100
# 164/164 - 0s - loss: 0.4622 - accuracy: 0.7887
# Epoch 7/100
# 164/164 - 0s - loss: 0.4362 - accuracy: 0.7995
# Epoch 8/100
# 164/164 - 0s - loss: 0.4186 - accuracy: 0.8062
# Epoch 9/100
# 164/164 - 0s - loss: 0.4002 - accuracy: 0.8241
# Epoch 10/100
# 164/164 - 0s - loss: 0.3859 - accuracy: 0.8295
# Epoch 11/100
# 164/164 - 0s - loss: 0.3760 - accuracy: 0.8238
# Epoch 12/100
# 164/164 - 0s - loss: 0.3683 - accuracy: 0.8293
# Epoch 13/100
# 164/164 - 0s - loss: 0.3622 - accuracy: 0.8299
# Epoch 14/100
# 164/164 - 0s - loss: 0.3576 - accuracy: 0.8402
# Epoch 15/100
# 164/164 - 0s - loss: 0.3538 - accuracy: 0.8369
# Epoch 16/100
# 164/164 - 0s - loss: 0.3494 - accuracy: 0.8405
# Epoch 17/100
# 164/164 - 0s - loss: 0.3461 - accuracy: 0.8428
# Epoch 18/100
# 164/164 - 0s - loss: 0.3416 - accuracy: 0.8426
# Epoch 19/100
# 164/164 - 0s - loss: 0.3388 - accuracy: 0.8432
# Epoch 20/100
# 164/164 - 0s - loss: 0.3361 - accuracy: 0.8497
# Epoch 21/100
# 164/164 - 0s - loss: 0.3330 - accuracy: 0.8514
# Epoch 22/100
# 164/164 - 0s - loss: 0.3302 - accuracy: 0.8537
# Epoch 23/100
# 164/164 - 0s - loss: 0.3286 - accuracy: 0.8510
# Epoch 24/100
# 164/164 - 0s - loss: 0.3268 - accuracy: 0.8543
# Epoch 25/100
# 164/164 - 0s - loss: 0.3237 - accuracy: 0.8549
# Epoch 26/100
# 164/164 - 0s - loss: 0.3243 - accuracy: 0.8501
# Epoch 27/100
# 164/164 - 0s - loss: 0.3223 - accuracy: 0.8554
# Epoch 28/100
# 164/164 - 0s - loss: 0.3190 - accuracy: 0.8592
# Epoch 29/100
# 164/164 - 0s - loss: 0.3180 - accuracy: 0.8592
# Epoch 30/100
# 164/164 - 0s - loss: 0.3171 - accuracy: 0.8583
# Epoch 31/100
# 164/164 - 0s - loss: 0.3151 - accuracy: 0.8591
# Epoch 32/100
# 164/164 - 0s - loss: 0.3144 - accuracy: 0.8611
# Epoch 33/100
# 164/164 - 0s - loss: 0.3127 - accuracy: 0.8594
# Epoch 34/100
# 164/164 - 0s - loss: 0.3110 - accuracy: 0.8608
# Epoch 35/100
# 164/164 - 0s - loss: 0.3113 - accuracy: 0.8594
# Epoch 36/100
# 164/164 - 0s - loss: 0.3091 - accuracy: 0.8615
# Epoch 37/100
# 164/164 - 0s - loss: 0.3084 - accuracy: 0.8623
# Epoch 38/100
# 164/164 - 0s - loss: 0.3066 - accuracy: 0.8673
# Epoch 39/100
# 164/164 - 0s - loss: 0.3067 - accuracy: 0.8671
# Epoch 40/100
# 164/164 - 0s - loss: 0.3059 - accuracy: 0.8636
# Epoch 41/100
# 164/164 - 0s - loss: 0.3039 - accuracy: 0.8680
# Epoch 42/100
# 164/164 - 0s - loss: 0.3037 - accuracy: 0.8680
# Epoch 43/100
# 164/164 - 0s - loss: 0.3026 - accuracy: 0.8671
# Epoch 44/100
# 164/164 - 0s - loss: 0.3023 - accuracy: 0.8674
# Epoch 45/100
# 164/164 - 0s - loss: 0.3019 - accuracy: 0.8673
# Epoch 46/100
# 164/164 - 0s - loss: 0.3012 - accuracy: 0.8676
# Epoch 47/100
# 164/164 - 0s - loss: 0.2996 - accuracy: 0.8680
# Epoch 48/100
# 164/164 - 0s - loss: 0.2995 - accuracy: 0.8692
# Epoch 49/100
# 164/164 - 0s - loss: 0.2984 - accuracy: 0.8699
# Epoch 50/100
# 164/164 - 0s - loss: 0.2977 - accuracy: 0.8714
# Epoch 51/100
# 164/164 - 0s - loss: 0.2963 - accuracy: 0.8743
# Epoch 52/100
# 164/164 - 0s - loss: 0.2949 - accuracy: 0.8705
# Epoch 53/100
# 164/164 - 0s - loss: 0.2961 - accuracy: 0.8692
# Epoch 54/100
# 164/164 - 0s - loss: 0.2939 - accuracy: 0.8743
# Epoch 55/100
# 164/164 - 0s - loss: 0.2941 - accuracy: 0.8716
# Epoch 56/100
# 164/164 - 0s - loss: 0.2927 - accuracy: 0.8756
# Epoch 57/100
# 164/164 - 0s - loss: 0.2935 - accuracy: 0.8707
# Epoch 58/100
# 164/164 - 0s - loss: 0.2904 - accuracy: 0.8760
# Epoch 59/100
# 164/164 - 0s - loss: 0.2925 - accuracy: 0.8739
# Epoch 60/100
# 164/164 - 0s - loss: 0.2900 - accuracy: 0.8766
# Epoch 61/100
# 164/164 - 0s - loss: 0.2894 - accuracy: 0.8758
# Epoch 62/100
# 164/164 - 0s - loss: 0.2885 - accuracy: 0.8764
# Epoch 63/100
# 164/164 - 0s - loss: 0.2885 - accuracy: 0.8762
# Epoch 64/100
# 164/164 - 0s - loss: 0.2873 - accuracy: 0.8764
# Epoch 65/100
# 164/164 - 0s - loss: 0.2876 - accuracy: 0.8777
# Epoch 66/100
# 164/164 - 0s - loss: 0.2851 - accuracy: 0.8789
# Epoch 67/100
# 164/164 - 0s - loss: 0.2869 - accuracy: 0.8783
# Epoch 68/100
# 164/164 - 0s - loss: 0.2853 - accuracy: 0.8789
# Epoch 69/100
# 164/164 - 0s - loss: 0.2849 - accuracy: 0.8755
# Epoch 70/100
# 164/164 - 0s - loss: 0.2842 - accuracy: 0.8816
# Epoch 71/100
# 164/164 - 0s - loss: 0.2829 - accuracy: 0.8814
# Epoch 72/100
# 164/164 - 0s - loss: 0.2830 - accuracy: 0.8802
# Epoch 73/100
# 164/164 - 0s - loss: 0.2827 - accuracy: 0.8833
# Epoch 74/100
# 164/164 - 0s - loss: 0.2823 - accuracy: 0.8802
# Epoch 75/100
# 164/164 - 0s - loss: 0.2827 - accuracy: 0.8796
# Epoch 76/100
# 164/164 - 0s - loss: 0.2811 - accuracy: 0.8804
# Epoch 77/100
# 164/164 - 0s - loss: 0.2813 - accuracy: 0.8819
# Epoch 78/100
# 164/164 - 0s - loss: 0.2793 - accuracy: 0.8823
# Epoch 79/100
# 164/164 - 0s - loss: 0.2800 - accuracy: 0.8827
# Epoch 80/100
# 164/164 - 0s - loss: 0.2800 - accuracy: 0.8819
# Epoch 81/100
# 164/164 - 0s - loss: 0.2794 - accuracy: 0.8802
# Epoch 82/100
# 164/164 - 0s - loss: 0.2786 - accuracy: 0.8827
# Epoch 83/100
# 164/164 - 0s - loss: 0.2780 - accuracy: 0.8819
# Epoch 84/100
# 164/164 - 0s - loss: 0.2784 - accuracy: 0.8819
# Epoch 85/100
# 164/164 - 0s - loss: 0.2772 - accuracy: 0.8833
# Epoch 86/100
# 164/164 - 0s - loss: 0.2796 - accuracy: 0.8817
# Epoch 87/100
# 164/164 - 0s - loss: 0.2777 - accuracy: 0.8848
# Epoch 88/100
# 164/164 - 0s - loss: 0.2767 - accuracy: 0.8859
# Epoch 89/100
# 164/164 - 0s - loss: 0.2752 - accuracy: 0.8871
# Epoch 90/100
# 164/164 - 0s - loss: 0.2765 - accuracy: 0.8865
# Epoch 91/100
# 164/164 - 0s - loss: 0.2750 - accuracy: 0.8882
# Epoch 92/100
# 164/164 - 0s - loss: 0.2759 - accuracy: 0.8846
# Epoch 93/100
# 164/164 - 0s - loss: 0.2749 - accuracy: 0.8890
# Epoch 94/100
# 164/164 - 0s - loss: 0.2742 - accuracy: 0.8850
# Epoch 95/100
# 164/164 - 0s - loss: 0.2753 - accuracy: 0.8856
# Epoch 96/100
# 164/164 - 0s - loss: 0.2740 - accuracy: 0.8871
# Epoch 97/100
# 164/164 - 0s - loss: 0.2749 - accuracy: 0.8833
# Epoch 98/100
# 164/164 - 0s - loss: 0.2741 - accuracy: 0.8846
# Epoch 99/100
# 164/164 - 0s - loss: 0.2727 - accuracy: 0.8879
# Epoch 100/100
# 164/164 - 0s - loss: 0.2735 - accuracy: 0.8894

# %% [markdown]
# # Deep Learning

# %%
deep_model = Sequential()
deep_model.add(Dense(units=10, activation='relu', input_dim=40))
deep_model.add(Dense(units=10, activation='relu'))
deep_model.add(Dense(units=3, activation='softmax'))

# %%
deep_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 10)                410
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                110
# _________________________________________________________________
# dense_4 (Dense)              (None, 3)                 33
# =================================================================
# Total params: 553
# Trainable params: 553
# Non-trainable params: 0
# _________________________________________________________________

# %%
deep_model.compile(optimizer='adam',
                   loss='categorical_crossentropy',
                   metrics=['accuracy'])

deep_model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=100,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/100
# 164/164 - 0s - loss: 1.0331 - accuracy: 0.4743
# Epoch 2/100
# 164/164 - 0s - loss: 0.8163 - accuracy: 0.6016
# Epoch 3/100
# 164/164 - 0s - loss: 0.4921 - accuracy: 0.7557
# Epoch 4/100
# 164/164 - 0s - loss: 0.4074 - accuracy: 0.8014
# Epoch 5/100
# 164/164 - 0s - loss: 0.3893 - accuracy: 0.8098
# Epoch 6/100
# 164/164 - 0s - loss: 0.3805 - accuracy: 0.8127
# Epoch 7/100
# 164/164 - 0s - loss: 0.3726 - accuracy: 0.8180
# Epoch 8/100
# 164/164 - 0s - loss: 0.3673 - accuracy: 0.8234
# Epoch 9/100
# 164/164 - 0s - loss: 0.3625 - accuracy: 0.8243
# Epoch 10/100
# 164/164 - 0s - loss: 0.3596 - accuracy: 0.8289
# Epoch 11/100
# 164/164 - 0s - loss: 0.3567 - accuracy: 0.8278
# Epoch 12/100
# 164/164 - 0s - loss: 0.3521 - accuracy: 0.8373
# Epoch 13/100
# 164/164 - 0s - loss: 0.3507 - accuracy: 0.8329
# Epoch 14/100
# 164/164 - 0s - loss: 0.3470 - accuracy: 0.8299
# Epoch 15/100
# 164/164 - 0s - loss: 0.3448 - accuracy: 0.8335
# Epoch 16/100
# 164/164 - 0s - loss: 0.3430 - accuracy: 0.8358
# Epoch 17/100
# 164/164 - 0s - loss: 0.3403 - accuracy: 0.8356
# Epoch 18/100
# 164/164 - 0s - loss: 0.3378 - accuracy: 0.8396
# Epoch 19/100
# 164/164 - 0s - loss: 0.3364 - accuracy: 0.8404
# Epoch 20/100
# 164/164 - 0s - loss: 0.3339 - accuracy: 0.8432
# Epoch 21/100
# 164/164 - 0s - loss: 0.3318 - accuracy: 0.8428
# Epoch 22/100
# 164/164 - 0s - loss: 0.3335 - accuracy: 0.8413
# Epoch 23/100
# 164/164 - 0s - loss: 0.3303 - accuracy: 0.8438
# Epoch 24/100
# 164/164 - 0s - loss: 0.3292 - accuracy: 0.8423
# Epoch 25/100
# 164/164 - 0s - loss: 0.3264 - accuracy: 0.8478
# Epoch 26/100
# 164/164 - 0s - loss: 0.3245 - accuracy: 0.8491
# Epoch 27/100
# 164/164 - 0s - loss: 0.3232 - accuracy: 0.8480
# Epoch 28/100
# 164/164 - 0s - loss: 0.3229 - accuracy: 0.8505
# Epoch 29/100
# 164/164 - 0s - loss: 0.3217 - accuracy: 0.8474
# Epoch 30/100
# 164/164 - 0s - loss: 0.3180 - accuracy: 0.8554
# Epoch 31/100
# 164/164 - 0s - loss: 0.3170 - accuracy: 0.8562
# Epoch 32/100
# 164/164 - 0s - loss: 0.3185 - accuracy: 0.8528
# Epoch 33/100
# 164/164 - 0s - loss: 0.3175 - accuracy: 0.8529
# Epoch 34/100
# 164/164 - 0s - loss: 0.3143 - accuracy: 0.8529
# Epoch 35/100
# 164/164 - 0s - loss: 0.3105 - accuracy: 0.8554
# Epoch 36/100
# 164/164 - 0s - loss: 0.3102 - accuracy: 0.8573
# Epoch 37/100
# 164/164 - 0s - loss: 0.3107 - accuracy: 0.8552
# Epoch 38/100
# 164/164 - 0s - loss: 0.3079 - accuracy: 0.8585
# Epoch 39/100
# 164/164 - 0s - loss: 0.3062 - accuracy: 0.8550
# Epoch 40/100
# 164/164 - 0s - loss: 0.3039 - accuracy: 0.8629
# Epoch 41/100
# 164/164 - 0s - loss: 0.3042 - accuracy: 0.8606
# Epoch 42/100
# 164/164 - 0s - loss: 0.3042 - accuracy: 0.8611
# Epoch 43/100
# 164/164 - 0s - loss: 0.3037 - accuracy: 0.8600
# Epoch 44/100
# 164/164 - 0s - loss: 0.2997 - accuracy: 0.8608
# Epoch 45/100
# 164/164 - 0s - loss: 0.3028 - accuracy: 0.8625
# Epoch 46/100
# 164/164 - 0s - loss: 0.2983 - accuracy: 0.8632
# Epoch 47/100
# 164/164 - 0s - loss: 0.2998 - accuracy: 0.8615
# Epoch 48/100
# 164/164 - 0s - loss: 0.2980 - accuracy: 0.8659
# Epoch 49/100
# 164/164 - 0s - loss: 0.2970 - accuracy: 0.8661
# Epoch 50/100
# 164/164 - 0s - loss: 0.2951 - accuracy: 0.8642
# Epoch 51/100
# 164/164 - 0s - loss: 0.2939 - accuracy: 0.8676
# Epoch 52/100
# 164/164 - 0s - loss: 0.2942 - accuracy: 0.8669
# Epoch 53/100
# 164/164 - 0s - loss: 0.2930 - accuracy: 0.8671
# Epoch 54/100
# 164/164 - 0s - loss: 0.2912 - accuracy: 0.8707
# Epoch 55/100
# 164/164 - 0s - loss: 0.2923 - accuracy: 0.8716
# Epoch 56/100
# 164/164 - 0s - loss: 0.2888 - accuracy: 0.8722
# Epoch 57/100
# 164/164 - 0s - loss: 0.2911 - accuracy: 0.8726
# Epoch 58/100
# 164/164 - 0s - loss: 0.2892 - accuracy: 0.8673
# Epoch 59/100
# 164/164 - 0s - loss: 0.2903 - accuracy: 0.8692
# Epoch 60/100
# 164/164 - 0s - loss: 0.2851 - accuracy: 0.8724
# Epoch 61/100
# 164/164 - 0s - loss: 0.2874 - accuracy: 0.8709
# Epoch 62/100
# 164/164 - 0s - loss: 0.2844 - accuracy: 0.8732
# Epoch 63/100
# 164/164 - 0s - loss: 0.2847 - accuracy: 0.8749
# Epoch 64/100
# 164/164 - 0s - loss: 0.2830 - accuracy: 0.8772
# Epoch 65/100
# 164/164 - 0s - loss: 0.2842 - accuracy: 0.8743
# Epoch 66/100
# 164/164 - 0s - loss: 0.2802 - accuracy: 0.8793
# Epoch 67/100
# 164/164 - 0s - loss: 0.2797 - accuracy: 0.8747
# Epoch 68/100
# 164/164 - 0s - loss: 0.2797 - accuracy: 0.8791
# Epoch 69/100
# 164/164 - 0s - loss: 0.2796 - accuracy: 0.8770
# Epoch 70/100
# 164/164 - 0s - loss: 0.2783 - accuracy: 0.8795
# Epoch 71/100
# 164/164 - 0s - loss: 0.2760 - accuracy: 0.8816
# Epoch 72/100
# 164/164 - 0s - loss: 0.2754 - accuracy: 0.8812
# Epoch 73/100
# 164/164 - 0s - loss: 0.2754 - accuracy: 0.8821
# Epoch 74/100
# 164/164 - 0s - loss: 0.2777 - accuracy: 0.8795
# Epoch 75/100
# 164/164 - 0s - loss: 0.2743 - accuracy: 0.8825
# Epoch 76/100
# 164/164 - 0s - loss: 0.2754 - accuracy: 0.8798
# Epoch 77/100
# 164/164 - 0s - loss: 0.2748 - accuracy: 0.8795
# Epoch 78/100
# 164/164 - 0s - loss: 0.2723 - accuracy: 0.8844
# Epoch 79/100
# 164/164 - 0s - loss: 0.2708 - accuracy: 0.8833
# Epoch 80/100
# 164/164 - 0s - loss: 0.2725 - accuracy: 0.8833
# Epoch 81/100
# 164/164 - 0s - loss: 0.2695 - accuracy: 0.8819
# Epoch 82/100
# 164/164 - 0s - loss: 0.2710 - accuracy: 0.8850
# Epoch 83/100
# 164/164 - 0s - loss: 0.2718 - accuracy: 0.8854
# Epoch 84/100
# 164/164 - 0s - loss: 0.2684 - accuracy: 0.8861
# Epoch 85/100
# 164/164 - 0s - loss: 0.2685 - accuracy: 0.8854
# Epoch 86/100
# 164/164 - 0s - loss: 0.2691 - accuracy: 0.8854
# Epoch 87/100
# 164/164 - 0s - loss: 0.2671 - accuracy: 0.8846
# Epoch 88/100
# 164/164 - 0s - loss: 0.2702 - accuracy: 0.8867
# Epoch 89/100
# 164/164 - 0s - loss: 0.2657 - accuracy: 0.8903
# Epoch 90/100
# 164/164 - 0s - loss: 0.2658 - accuracy: 0.8875
# Epoch 91/100
# 164/164 - 0s - loss: 0.2653 - accuracy: 0.8880
# Epoch 92/100
# 164/164 - 0s - loss: 0.2655 - accuracy: 0.8838
# Epoch 93/100
# 164/164 - 0s - loss: 0.2642 - accuracy: 0.8888
# Epoch 94/100
# 164/164 - 0s - loss: 0.2676 - accuracy: 0.8875
# Epoch 95/100
# 164/164 - 0s - loss: 0.2655 - accuracy: 0.8879
# Epoch 96/100
# 164/164 - 0s - loss: 0.2629 - accuracy: 0.8903
# Epoch 97/100
# 164/164 - 0s - loss: 0.2632 - accuracy: 0.8879
# Epoch 98/100
# 164/164 - 0s - loss: 0.2679 - accuracy: 0.8846
# Epoch 99/100
# 164/164 - 0s - loss: 0.2659 - accuracy: 0.8865
# Epoch 100/100
# 164/164 - 0s - loss: 0.2618 - accuracy: 0.8924

# %% [markdown]
# # Compare 2 models (Neural Networks and Deep Learning

# %%
 #Neural Networks
model_loss, model_accuracy = model.evaluate(
    X_test_scaled, y_test_categorical, verbose=2)
print(
    f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 55/55 - 0s - loss: 0.2995 - accuracy: 0.8793
# Normal Neural Network - Loss: 0.2995090186595917, Accuracy: 0.8792906403541565

# %%
# Deep Learning
model_loss, model_accuracy = deep_model.evaluate(
    X_test_scaled, y_test_categorical, verbose=2)
print(f"Deep Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 55/55 - 0s - loss: 0.2697 - accuracy: 0.8862
# Deep Neural Network - Loss: 0.26974767446517944, Accuracy: 0.8861556053161621

# %% [markdown]
# # Save the Model

# %%
# Save your model

#import joblib
#filename = 'ofunkey_normalneural.sav'
#joblib.dump(model, filename)

# %%
# Save Deep_model

import joblib
filename2 = 'MYCROFTXTREEM_deeplearning.sav'
joblib.dump(deep_model, filename2)

# %% [markdown]
# # Conclusion
#
#
#
#
# The accuracy of Neural Networks model and Deep Learning model is quite close without hyperparameter tuning and less training. Neural Network model: 0.8792906403541565 Deep Learning model: 0.8861556053161621
#
# However, Random Forest model's best score of (0.8987221563248168) seems better than SVM model (0.8733555767397521) when comparing the scores with hyperparameter tuning.
