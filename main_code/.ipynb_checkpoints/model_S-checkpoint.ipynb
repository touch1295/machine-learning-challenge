# %%
# Import libraries
import pandas as pd

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
# Read CSV file 
df = pd.read_csv("exoplanet_data.csv")

# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')

# Drop the null rows
df = df.dropna()
df.head(10)
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
# 5       CONFIRMED              0              0              0              0
# 6       CONFIRMED              0              0              0              0
# 7       CONFIRMED              0              0              0              0
# 8       CONFIRMED              0              1              0              0
# 9       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# ...

# %% [markdown]
# # Select features (columns)

# %%
# Set features
# selected_features = df[['names', 'of', 'selected', 'features', 'here']]
selected_features = df

# %% [markdown]
# # Create a Train Test Split
# Use koi_disposition for the y values

# %%
# Assign x and y values
X = df.drop("koi_disposition", axis=1)
y = df["koi_disposition"]

print(X.shape, y.shape)
# Out:
# (6991, 40) (6991,)

# %%
# Import Dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical

# Split data into training and testing
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=115, stratify=y)

# %%
X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 2700              0              0              0              0   31.804760
# 21                0              0              0              0    4.280964
# 5040              0              1              1              0    0.829019
# 2795              0              0              1              0    1.387838
# 1765              0              0              0              0   14.383227
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 2700         0.000091        -0.000091    190.25413           0.00224
# 21           0.000006        -0.000006    171.89659           0.00115
# 5040         0.000002        -0.000002    131.46667           0.00401
# 2795         0.000006        -0.000006    132.11351           0.00318
# 1765         0.000086        -0.000086    140.57648           0.00530
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# ...

# %% [markdown]
# # Pre-processing
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale the data
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# # Train Model - SVM
# Use Support Vector Machine (SVM) model

# %%
# Create the SVC Model
from sklearn.svm import SVC 
model = SVC(kernel='linear')
model.fit(X_train_scaled, y_train)
# Out:
# SVC(kernel='linear')

# %%
print(f"Training Data Score: {model.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {model.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 0.8498950982262063
# Testing Data Score: 0.8329519450800915

# %% [markdown]
# # Hyperparameter Tuning
# Use GridSearchCV to tune the SVM model's parameters

# %%
# Create the GridSearchCV model
from sklearn.model_selection import GridSearchCV
param_grid = {'C': [1, 5, 10],
              'gamma': [0.0001, 0.001, 0.01]}
grid = GridSearchCV(model, param_grid, verbose=3)

# %%
# Fit the SVM model using the grid search estimator. 
# This will take the SVM model and try each combination of parameters
grid.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] C=1, gamma=0.0001 ...............................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ................... C=1, gamma=0.0001, score=0.842, total=   0.3s
# [CV] C=1, gamma=0.0001 ...............................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s remaining:    0.0s
# [CV] ................... C=1, gamma=0.0001, score=0.860, total=   0.3s
# [CV] C=1, gamma=0.0001 ...............................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.6s remaining:    0.0s
# [CV] ................... C=1, gamma=0.0001, score=0.841, total=   0.3s
# [CV] C=1, gamma=0.0001 ...............................................
# [CV] ................... C=1, gamma=0.0001, score=0.843, total=   0.3s
# [CV] C=1, gamma=0.0001 ...............................................
# ...

# %%
# List the best parameters for this dataset
print(f"Best Parameters: {grid.best_params_}")

# List the best score
print(f"Best Score: {grid.best_score_}")
# Out:
# Best Parameters: {'C': 10, 'gamma': 0.0001}
# Best Score: 0.8733555767397521

# %%
print(f"Training Grid Score: {grid.score(X_train_scaled, y_train)}")
print(f"Testing Grid Score: {grid.score(X_test_scaled, y_test)}")
# Out:
# Training Grid Score: 0.8775510204081632
# Testing Grid Score: 0.8655606407322655

# %%
 #Make predictions with the hypertuned model
predictions = grid.predict(X_test_scaled)

# %%
# Calculate classification report
from sklearn.metrics import classification_report
print(classification_report(y_test, predictions))
# Out:
#                 precision    recall  f1-score   support
#
#      CANDIDATE       0.83      0.58      0.68       422
#      CONFIRMED       0.70      0.88      0.78       450
# FALSE POSITIVE       0.99      1.00      0.99       876
#
#       accuracy                           0.87      1748
#      macro avg       0.84      0.82      0.82      1748
#   weighted avg       0.87      0.87      0.86      1748

# %% [markdown]
# # Save the Model

# %%
# Save the model 
import joblib
filename = 'MYCROFTXTREEM_SVM.sav'
joblib.dump(model, filename)
# Out:
# ['MYCROFTXTREEM_SVM.sav']

# %% [markdown]
# Conclusion
#
#
#
#
#
# The f1-score of FALSE POSITIVE for SVM model is closer to 1 (0.99) meaning it can predict FALSE POSITIVE well and it's reliable.
#
# The Grid score from the hyperparameter tuning boasts the SVM score higher Training Data Score: 0.8498950982262063 changes to 0.8775510204081632 Testing Data Score: 0.8329519450800915 changes to 0.8655606407322655 Best Score: 0.8706847224871257
#
# However, Random Forest model's best score of (0.8987221563248168) seems better than SVM model (0.8706847224871257) when comparing the scores.
